# %%
from google.colab import drive
drive.mount('/content/drive')
# !pip install tensorflow_addons
# %cd '/content/drive/MyDrive/generative/GANs'
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Requirement already satisfied: tensorflow_addons in /usr/local/lib/python3.7/dist-packages (0.13.0)
# Requirement already satisfied: typeguard>=2.7 in /usr/local/lib/python3.7/dist-packages (from tensorflow_addons) (2.7.1)
# /content/drive/MyDrive/generative/GANs

# %%
from models import DCGAN 


if __name__ == '__main__':
    MODE =  'build'
    BATCH_SIZE = 64
    MAX_EPOCHS = 6000
    SHOW_EVERY_N = 600

    # Model
    model = DCGAN(
        data_name='mnist',
        ID=0,
        )
    model.summary()
    if MODE == 'load':
        model.load_models()

    # Load Data
    (x_train, y_train), _ = model.loader.load_mnist()

    # Train
    model.train(
        BATCH_SIZE,
        MAX_EPOCHS,
        SHOW_EVERY_N,
        train_data=[x_train, y_train]
        )
# Out:
# ############### Generator ###############
# Model: "model_6"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# G_input (InputLayer)         [(None, 100)]             0
# _________________________________________________________________
# dense_4 (Dense)              (None, 3136)              316736
# _________________________________________________________________
# batch_normalization_8 (Batch (None, 3136)              12544
# _________________________________________________________________
# re_lu_8 (ReLU)               (None, 3136)              0
# _________________________________________________________________
# reshape_2 (Reshape)          (None, 7, 7, 64)          0
# _________________________________________________________________
# up_sampling2d_4 (UpSampling2 (None, 14, 14, 64)        0
# _________________________________________________________________
# G_conv_0 (Conv2D)            (None, 14, 14, 128)       204928
# _________________________________________________________________
# batch_normalization_9 (Batch (None, 14, 14, 128)       512
# _________________________________________________________________
# re_lu_9 (ReLU)               (None, 14, 14, 128)       0
# _________________________________________________________________
# up_sampling2d_5 (UpSampling2 (None, 28, 28, 128)       0
# _________________________________________________________________
# G_conv_1 (Conv2D)            (None, 28, 28, 64)        204864
# _________________________________________________________________
# batch_normalization_10 (Batc (None, 28, 28, 64)        256
# _________________________________________________________________
# re_lu_10 (ReLU)              (None, 28, 28, 64)        0
# _________________________________________________________________
# G_conv_2 (Conv2DTranspose)   (None, 28, 28, 64)        102464
# _________________________________________________________________
# batch_normalization_11 (Batc (None, 28, 28, 64)        256
# _________________________________________________________________
# re_lu_11 (ReLU)              (None, 28, 28, 64)        0
# _________________________________________________________________
# G_conv_3 (Conv2DTranspose)   (None, 28, 28, 1)         1601
# _________________________________________________________________
# activation_2 (Activation)    (None, 28, 28, 1)         0
# =================================================================
# Total params: 844,161
# Trainable params: 837,377
# Non-trainable params: 6,784
# _________________________________________________________________
# ############### Discriminator ###############
# Model: "model_7"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# D_input (InputLayer)         [(None, 28, 28, 1)]       0
# _________________________________________________________________
# D_conv_0 (Conv2D)            (None, 14, 14, 64)        1664
# _________________________________________________________________
# leaky_re_lu_8 (LeakyReLU)    (None, 14, 14, 64)        0
# _________________________________________________________________
# dropout_8 (Dropout)          (None, 14, 14, 64)        0
# _________________________________________________________________
# D_conv_1 (Conv2D)            (None, 7, 7, 64)          102464
# _________________________________________________________________
# leaky_re_lu_9 (LeakyReLU)    (None, 7, 7, 64)          0
# _________________________________________________________________
# dropout_9 (Dropout)          (None, 7, 7, 64)          0
# _________________________________________________________________
# D_conv_2 (Conv2D)            (None, 4, 4, 128)         204928
# _________________________________________________________________
# leaky_re_lu_10 (LeakyReLU)   (None, 4, 4, 128)         0
# _________________________________________________________________
# dropout_10 (Dropout)         (None, 4, 4, 128)         0
# _________________________________________________________________
# D_conv_3 (Conv2D)            (None, 4, 4, 128)         409728
# _________________________________________________________________
# leaky_re_lu_11 (LeakyReLU)   (None, 4, 4, 128)         0
# _________________________________________________________________
# dropout_11 (Dropout)         (None, 4, 4, 128)         0
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 2048)              0
# _________________________________________________________________
# dense_5 (Dense)              (None, 1)                 2049
# =================================================================
# Total params: 720,833
# Trainable params: 720,833
# Non-trainable params: 0
# _________________________________________________________________
# ############### Whole_Model ###############
# Model: "model_8"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# model_input (InputLayer)     [(None, 100)]             0
# _________________________________________________________________
# model_6 (Functional)         (None, 28, 28, 1)         844161
# _________________________________________________________________
# model_7 (Functional)         (None, 1)                 720833
# =================================================================
# Total params: 1,564,994
# Trainable params: 1,558,210
# Non-trainable params: 6,784
# _________________________________________________________________
# [Epochs 0/6000] [D Acc 33.59 Total 0.6950 Real 0.6887 Fake 0.7012] [G 0.6432] Time 0:00:01.415358
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# [Epochs 1/6000] [D Acc 50.00 Total 0.6284 Real 0.5380 Fake 0.7187] [G 0.2711] Time 0:00:02.550661
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# [Epochs 2/6000] [D Acc 50.00 Total 0.5336 Real 0.1131 Fake 0.9540] [G 0.0534] Time 0:00:03.521383
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# [Epochs 3/6000] [D Acc 98.44 Total 0.3541 Real 0.0176 Fake 0.6905] [G 0.0484] Time 0:00:06.401313
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# [Epochs 4/6000] [D Acc 100.00 Total 0.3535 Real 0.0232 Fake 0.6838] [G 0.0055] Time 0:00:07.785380
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# [Epochs 5/6000] [D Acc 100.00 Total 0.3353 Real 0.0027 Fake 0.6680] [G 0.0007] Time 0:00:08.746531
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# [Epochs 6/6000] [D Acc 100.00 Total 0.3124 Real 0.0006 Fake 0.6241] [G 0.0001] Time 0:00:10.354953
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# [Epochs 7/6000] [D Acc 100.00 Total 0.2444 Real 0.0004 Fake 0.4883] [G 0.0000] Time 0:00:11.381051
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# [Epochs 8/6000] [D Acc 100.00 Total 0.1093 Real 0.0001 Fake 0.2186] [G 0.0000] Time 0:00:12.349206
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# [Epochs 9/6000] [D Acc 100.00 Total 0.0167 Real 0.0001 Fake 0.0333] [G 0.0000] Time 0:00:13.357478
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# [Epochs 10/6000] [D Acc 96.09 Total 0.2440 Real 0.2356 Fake 0.2524] [G 0.0000] Time 0:00:14.681798
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# [Epochs 11/6000] [D Acc 100.00 Total 0.0034 Real 0.0000 Fake 0.0067] [G 0.0101] Time 0:00:15.566762
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# [Epochs 12/6000] [D Acc 100.00 Total 0.0031 Real 0.0003 Fake 0.0059] [G 0.1151] Time 0:00:16.619846
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# [Epochs 13/6000] [D Acc 100.00 Total 0.0281 Real 0.0039 Fake 0.0522] [G 17.3308] Time 0:00:17.564339
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# [Epochs 14/6000] [D Acc 3.91 Total 7.7955 Real 8.2292 Fake 7.3617] [G 0.0170] Time 0:00:18.769069
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# [Epochs 15/6000] [D Acc 99.22 Total 0.1666 Real 0.0001 Fake 0.3330] [G 1.8600] Time 0:00:20.555245
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# [Epochs 16/6000] [D Acc 50.00 Total 1.3075 Real 0.0401 Fake 2.5749] [G 1.6121] Time 0:00:22.010887
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# [Epochs 17/6000] [D Acc 13.28 Total 1.0078 Real 1.2663 Fake 0.7494] [G 0.8199] Time 0:00:23.067076
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# [Epochs 18/6000] [D Acc 69.53 Total 0.5969 Real 0.4818 Fake 0.7119] [G 0.8503] Time 0:00:23.962803
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# [Epochs 19/6000] [D Acc 98.44 Total 0.4736 Real 0.4531 Fake 0.4940] [G 0.9315] Time 0:00:25.143204
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# [Epochs 20/6000] [D Acc 96.09 Total 0.4005 Real 0.4253 Fake 0.3756] [G 0.6732] Time 0:00:26.311394
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# [Epochs 21/6000] [D Acc 87.50 Total 0.3757 Real 0.2419 Fake 0.5094] [G 0.3039] Time 0:00:27.794335
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# [Epochs 22/6000] [D Acc 78.91 Total 0.4213 Real 0.1203 Fake 0.7222] [G 0.1390] Time 0:00:28.807154
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# [Epochs 23/6000] [D Acc 88.28 Total 0.3350 Real 0.1159 Fake 0.5540] [G 0.1140] Time 0:00:29.770102
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# [Epochs 24/6000] [D Acc 90.62 Total 0.3000 Real 0.1322 Fake 0.4677] [G 0.1026] Time 0:00:30.681829
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# [Epochs 25/6000] [D Acc 100.00 Total 0.1520 Real 0.0660 Fake 0.2380] [G 0.1402] Time 0:00:31.670165
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# [Epochs 26/6000] [D Acc 97.66 Total 0.2052 Real 0.1340 Fake 0.2764] [G 0.0997] Time 0:00:32.742621
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# [Epochs 27/6000] [D Acc 80.47 Total 0.4150 Real 0.2324 Fake 0.5976] [G 0.2370] Time 0:00:33.777084
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# [Epochs 28/6000] [D Acc 67.19 Total 0.6605 Real 0.5443 Fake 0.7767] [G 0.3310] Time 0:00:34.730595
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# [Epochs 29/6000] [D Acc 39.06 Total 0.9286 Real 0.6825 Fake 1.1748] [G 0.5977] Time 0:00:36.460542
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# [Epochs 30/6000] [D Acc 60.16 Total 0.5491 Real 0.3457 Fake 0.7524] [G 0.7890] Time 0:00:37.405904
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-5-78813556451d> in <module>()
#      25         MAX_EPOCHS,
#      26         SHOW_EVERY_N,
# ---> 27         train_data=[x_train, y_train]
#      28         )
#
# /content/drive/MyDrive/generative/GANs/models/dcgan.py in train(self, batch_size, max_epochs, show_every_n, train_data, train_batch)
#     270
#     271                     self.show_img(self.generator, self.z_dim, file_name='sample_{}.png'.format(epoch), color='gray')
# --> 272                     self.save_weights(file_name='weights_{}.h5'.format(epoch))
#     273                     self.save_models(epoch=epoch)
#     274
#
# /content/drive/MyDrive/generative/GANs/models/basemodel.py in save_weights(self, file_name)
#     103         for name, model in self.models.items():
#     104             file = os.path.join(folder, name + file_name)
# --> 105             model.save_weights(file)
#     106
#     107     def save_models(self, epoch=''):
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/engine/training.py in save_weights(self, filepath, overwrite, save_format, options)
#    2215         return
#    2216     if save_format == 'h5':
# -> 2217       with h5py.File(filepath, 'w') as f:
#    2218         hdf5_format.save_weights_to_hdf5_group(f, self.layers)
#    2219     else:
#
# /usr/local/lib/python3.7/dist-packages/h5py/_hl/files.py in __init__(self, name, mode, driver, libver, userblock_size, swmr, rdcc_nslots, rdcc_nbytes, rdcc_w0, track_order, fs_strategy, fs_persist, fs_threshold, **kwds)
#     425                                fapl, fcpl=make_fcpl(track_order=track_order, fs_strategy=fs_strategy,
#     426                                fs_persist=fs_persist, fs_threshold=fs_threshold),
# --> 427                                swmr=swmr)
#     428
#     429             if isinstance(libver, tuple):
#
# /usr/local/lib/python3.7/dist-packages/h5py/_hl/files.py in make_fid(name, mode, userblock_size, fapl, fcpl, swmr)
#     194         fid = h5f.create(name, h5f.ACC_EXCL, fapl=fapl, fcpl=fcpl)
#     195     elif mode == 'w':
# --> 196         fid = h5f.create(name, h5f.ACC_TRUNC, fapl=fapl, fcpl=fcpl)
#     197     elif mode == 'a':
#     198         # Open in append mode (read/write).
#
# h5py/_objects.pyx in h5py._objects.with_phil.wrapper()
#
# h5py/_objects.pyx in h5py._objects.with_phil.wrapper()
#
# h5py/h5f.pyx in h5py.h5f.create()
#
# OSError: Unable to create file (unable to open file: name = './run/DCGAN/0_mnist/weights/Whole_Modelweights_30.h5', errno = 2, error message = 'No such file or directory', flags = 13, o_flags = 242)
