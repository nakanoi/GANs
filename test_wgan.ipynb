# %%
from google.colab import drive
drive.mount('/content/drive')
# !pip install tensorflow_addons
# %cd '/content/drive/MyDrive/generative/GANs'
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Requirement already satisfied: tensorflow_addons in /usr/local/lib/python3.7/dist-packages (0.13.0)
# Requirement already satisfied: typeguard>=2.7 in /usr/local/lib/python3.7/dist-packages (from tensorflow_addons) (2.7.1)
# /content/drive/MyDrive/generative/GANs

# %%
from models import WGAN 


if __name__ == '__main__':
    MODE =  'build'
    BATCH_SIZE = 64
    MAX_EPOCHS = 6000
    SHOW_EVERY_N = 600

    # Model
    model = WGAN(
        data_name='mnist',
        ID=0,
        )
    model.summary()
    if MODE == 'load':
        model.load_models()

    # Load Data
    (x_train, y_train), _ = model.loader.load_mnist()

    # Train
    model.train(
        BATCH_SIZE,
        MAX_EPOCHS,
        SHOW_EVERY_N,
        train_data=[x_train, y_train]
        )
# Out:
# ############### Discriminator ###############
# Model: "model_7"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_5 (InputLayer)         [(None, 28, 28, 1)]       0
# _________________________________________________________________
# di_conv_0 (Conv2D)           (None, 14, 14, 64)        1664
# _________________________________________________________________
# leaky_re_lu_20 (LeakyReLU)   (None, 14, 14, 64)        0
# _________________________________________________________________
# di_conv_1 (Conv2D)           (None, 7, 7, 128)         204928
# _________________________________________________________________
# leaky_re_lu_21 (LeakyReLU)   (None, 7, 7, 128)         0
# _________________________________________________________________
# di_conv_2 (Conv2D)           (None, 4, 4, 512)         1638912
# _________________________________________________________________
# leaky_re_lu_22 (LeakyReLU)   (None, 4, 4, 512)         0
# _________________________________________________________________
# di_conv_3 (Conv2D)           (None, 4, 4, 1024)        13108224
# _________________________________________________________________
# leaky_re_lu_23 (LeakyReLU)   (None, 4, 4, 1024)        0
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 16384)             0
# _________________________________________________________________
# dense_5 (Dense)              (None, 1)                 16385
# =================================================================
# Total params: 14,970,113
# Trainable params: 14,970,113
# Non-trainable params: 0
# _________________________________________________________________
# ############### Generator ###############
# Model: "model_6"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# Generator_input (InputLayer) [(None, 100)]             0
# _________________________________________________________________
# dense_4 (Dense)              (None, 3136)              316736
# _________________________________________________________________
# batch_normalization_8 (Batch (None, 3136)              12544
# _________________________________________________________________
# leaky_re_lu_16 (LeakyReLU)   (None, 3136)              0
# _________________________________________________________________
# reshape_2 (Reshape)          (None, 7, 7, 64)          0
# _________________________________________________________________
# up_sampling2d_4 (UpSampling2 (None, 14, 14, 64)        0
# _________________________________________________________________
# ge_conv_0 (Conv2D)           (None, 14, 14, 512)       819712
# _________________________________________________________________
# batch_normalization_9 (Batch (None, 14, 14, 512)       2048
# _________________________________________________________________
# leaky_re_lu_17 (LeakyReLU)   (None, 14, 14, 512)       0
# _________________________________________________________________
# up_sampling2d_5 (UpSampling2 (None, 28, 28, 512)       0
# _________________________________________________________________
# ge_conv_1 (Conv2D)           (None, 28, 28, 256)       3277056
# _________________________________________________________________
# batch_normalization_10 (Batc (None, 28, 28, 256)       1024
# _________________________________________________________________
# leaky_re_lu_18 (LeakyReLU)   (None, 28, 28, 256)       0
# _________________________________________________________________
# ge_conv2Trans_2 (Conv2DTrans (None, 28, 28, 128)       819328
# _________________________________________________________________
# batch_normalization_11 (Batc (None, 28, 28, 128)       512
# _________________________________________________________________
# leaky_re_lu_19 (LeakyReLU)   (None, 28, 28, 128)       0
# _________________________________________________________________
# ge_conv2Trans_3 (Conv2DTrans (None, 28, 28, 1)         3201
# _________________________________________________________________
# activation_2 (Activation)    (None, 28, 28, 1)         0
# =================================================================
# Total params: 5,252,161
# Trainable params: 5,244,097
# Non-trainable params: 8,064
# _________________________________________________________________
# ############### Combined ###############
# Model: "model_8"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_6 (InputLayer)         [(None, 100)]             0
# _________________________________________________________________
# model_6 (Functional)         (None, 28, 28, 1)         5252161
# _________________________________________________________________
# model_7 (Functional)         (None, 1)                 14970113
# =================================================================
# Total params: 20,222,274
# Trainable params: 20,214,210
# Non-trainable params: 8,064
# _________________________________________________________________
# [Epochs 0/6000] [D Acc 0.00 Total -0.0140 Real -0.0277 Fake -0.0004] [G -0.0005] Time 0:00:02.627083
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# [Epochs 1/6000] [D Acc 0.00 Total -0.0157 Real -0.0677 Fake 0.0363] [G -0.0210] Time 0:00:05.689745
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# [Epochs 2/6000] [D Acc 0.00 Total -0.0715 Real -0.2113 Fake 0.0683] [G -0.0926] Time 0:00:09.226304
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# [Epochs 3/6000] [D Acc 0.00 Total -0.0122 Real -0.2168 Fake 0.1924] [G -0.0789] Time 0:00:12.857114
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-6-1f72cd88cdec> in <module>()
#      25         MAX_EPOCHS,
#      26         SHOW_EVERY_N,
# ---> 27         train_data=[x_train, y_train]
#      28         )
#
# /content/drive/My Drive/generative/GANs/models/wgan.py in train(self, batch_size, max_epochs, show_every_n, clip, train_data, train_batch)
#     263             for epoch in range(max_epochs):
#     264                 for j in range(self.k):
# --> 265                     di = self.train_discriminator(x_train, batch_size, clip)
#     266                 ge = self.train_generator(batch_size)
#     267
#
# /content/drive/My Drive/generative/GANs/models/wgan.py in train_discriminator(self, x_train, batch_size, clip)
#     202         idcs = np.random.randint(0, x_train.shape[0], batch_size)
#     203         real_imgs = x_train[idcs]
# --> 204         di_real = self.discriminator.train_on_batch(real_imgs, real)
#     205
#     206         z = np.random.normal(0, 1, (batch_size, self.z_dim))
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/engine/training.py in train_on_batch(self, x, y, sample_weight, class_weight, reset_metrics, return_dict)
#    1823                                                     class_weight)
#    1824       self.train_function = self.make_train_function()
# -> 1825       logs = self.train_function(iterator)
#    1826
#    1827     if reset_metrics:
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/def_function.py in __call__(self, *args, **kwds)
#     887
#     888       with OptionalXlaContext(self._jit_compile):
# --> 889         result = self._call(*args, **kwds)
#     890
#     891       new_tracing_count = self.experimental_get_tracing_count()
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/def_function.py in _call(self, *args, **kwds)
#     915       # In this case we have created variables on the first call, so we run the
#     916       # defunned version which is guaranteed to never create variables.
# --> 917       return self._stateless_fn(*args, **kwds)  # pylint: disable=not-callable
#     918     elif self._stateful_fn is not None:
#     919       # Release the lock early so that multiple threads can perform the call
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/function.py in __call__(self, *args, **kwargs)
#    3022        filtered_flat_args) = self._maybe_define_function(args, kwargs)
#    3023     return graph_function._call_flat(
# -> 3024         filtered_flat_args, captured_inputs=graph_function.captured_inputs)  # pylint: disable=protected-access
#    3025
#    3026   @property
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1959       # No tape is watching; skip to running the function.
#    1960       return self._build_call_outputs(self._inference_function.call(
# -> 1961           ctx, args, cancellation_manager=cancellation_manager))
#    1962     forward_backward = self._select_forward_and_backward_functions(
#    1963         args,
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/function.py in call(self, ctx, args, cancellation_manager)
#     594               inputs=args,
#     595               attrs=attrs,
# --> 596               ctx=ctx)
#     597         else:
#     598           outputs = execute.execute_with_cancellation(
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      58     ctx.ensure_initialized()
#      59     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
# ---> 60                                         inputs, attrs, num_outputs)
#      61   except core._NotOkStatusException as e:
#      62     if name is not None:
#
# KeyboardInterrupt:
